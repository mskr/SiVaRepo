# %% [markdown]
# # Python - Schleifen
#
# Heute lernen wir Python und das Jupyter Notebook kennen.
# In diesem Notebook dreht es sich um Schleifen in Python.
# Wir werden lernen, den Computer zählen zu lassen und blitzschnell Summen zu berechnen.
# Zu jedem Unterthema gibt es eine Einleitung und Beispiele, die die Theorie näher erklären.
# Na dann, auf gehts!

# %% [markdown]
# ## Was ist eine Schleife?
#
# Eine Schleife steuert den Ablauf eines Computerprogramms. Man nutzt sie, um einen Teil des Codes sehr oft zu wiederholen, ohne diesen mehrmals aufzuschreiben.
#
# Man automatisiert also eine Sache, die sehr langweilig wäre, wenn man sie selbst machen müsste. Denn dafür sind Computer ja da!

# %% [markdown]
# ## Arten von Schleifen
#
# Es gibt nur einige wenige wichtige Arten von Schleifen.
#
# Art           | Was kann sie? | Beispiel
# :--------------|:-------:|------------:
# **while** | Etwas tun, **solange** ein bestimmter Zustand vorhanden ist | Solange ich noch nicht coden kann, weiter zu SiVa Kids kommen
# **for** | Etwas **für** für eine bestimmte Anzahl von Malen tun | Jede Person in der Klasse durchzählen

# %% [markdown]
# ## Wiederholung
#
# Wir wollen zuerst ein paar Grundlagen wiederholen.
#
# ### Print
# Mit der print() Funktion können wir Dinge auf dem Bildschirm ausgeben.

# %%
print('Hallo Welt')

# %% [markdown]
# ### Variablen
#
# In einer Variable lassen sich Daten speichern. So ähnlich wie wenn man Dinge in eine Schublade legt. Jede Variable hat einen Namen und einen Wert. Den Wert kann man sich wie den Inhalt vorstellen.

# %%
# Einen Wert zuweisen
meineVariable = 'Hallo'
print(meineVariable)

# Den Wert durch eine Operation verändern
meineVariable = meineVariable + ' Welt'
print(meineVariable)

# %% [markdown]
# ## Die einfachste Schleife

# %% [markdown]
# Die einfachste Schleife ist eine **for** Schleife. Diese zählt einen bestimmten Bereich ab.

# %% [markdown]
# ### Beispiel: For Schleife
#
# Folgendes Beispiel zählt alle Ganzzahlen von 0 bis 4 ab und gibt sie aus.

# %%
for zahl in range(5):
    print(zahl)

# %% [markdown]
# ### Bereiche mit range erstellen
#
# Im obigen Beispiel haben wir die **range** Funktion benutzt. Diese stellt uns die Programmiersprache Python standardmäßig zur Verfügung. Range ist Englisch für Bereich.
#
# Die Funktion erwartet mindestens einen Parameter. Die Parameter sind vom Datentyp **int**, also Ganzzahlen. Daraus macht **range** den Datentyp **range**. Jedoch müssen wir dies nicht im Detail verstehen, um die Funktion zu benutzen.

# %% [markdown]
# #### Achtung: Wenn wir **range(5)** aufrufen, erstellen wir einen Bereich von 0 bis 4.

# %% [markdown]
# #### Komplexere Bereiche
#
# Wir können uns alle möglichen Bereiche definieren, die wir abzählen wollen.
#
# Insgesamt kann man der **range** Funktion drei Parameter mitgeben. Diese geben den Anfang, das Ende un die Schrittweite des Bereichs an.
#
# ![Range-Funktion](01--Schleifen/python-for-schleife-range-funktion.jpg)
#
# Das Diagramm zeigt die Parameter der **range** Funktion.

# %% [markdown]
# ## Bedingungen
#
# Nun wollen wir Bedingungen wiederholen. Wenn Du jedoch ganz neu bist, macht das nichts. Wir gehen alle Grundlagen durch.
#
# Bedingungen sind beim Programmieren sehr wichtig. Darüber hinaus hängen sie eng mit Schleifen zusammen.
#
# Eine Bedingung ist wie ein Konditionalsatz. Zum Beispiel: "Wenn es regnet, dann wird die Straße nass."

# %% [markdown]
# ### Beispiel: Bedingung
#
# Folgendes Code-Beispiel verdeutlicht, wie Bedingungen funktionieren. Wir nutzen das Schlüsselwort **if**. Das kann man übersetzen mit **falls** oder auch **wenn**.

# %%
regenStärke = 101

# %%
if regenStärke > 100:
    print('Die Straße wird nass.')

# %% [markdown]
# ## While Schleife
#
# Die einfachste Schleife ist eine **while** Schleife. Sie sieht fast genauso aus wie ein **if**, denn sie enthält eine Bedingung. Aber im Unterschied dazu wiederholt sie sich, solange die Bedingung zutrifft.

# %% [markdown]
# ### Beispiel: Den Computer zählen lassen
#
# Hierfür weisen wir einer Variable "zähler" den Wert 0 zu. Danach folgt eine while Schleife. Diese läuft, solange der Zähler kleiner als 10 ist. Im Schleifenkörper geben wir den Wert des Zählers aus und erhöhen diesen danach um 1.

# %%
zähler = 0
while zähler < 10:
    print(zähler)
    zähler = zähler + 1

# %% [markdown]
# ### Der Schleifenkörper
#
# Schleifen haben einen Körper. Der Schleifenkörper enthält Anweisungen, die wiederholt ausgeführt werden.
#
# Sicher weißt Du bereits ungefähr was Anweisungen sind, denn eigentlich nutzen wir die ganze Zeit Anweisungen.
#
# Ein anderes Wort für Anweisung ist Befehl. Wir sagen dem Computer also, was er tun soll. Genau darum geht es beim Coden.

# %% [markdown]
# ## Errors
#
# Error ist das englische Wort für Fehler. Tatsächlich machen selbst die besten Coder immer wieder Fehler. Sie sind aber auch besonders gut darin, diese zu finden.
#
# Errors können sehr nützlich sein. Nehmen wir beispielsweise an, wir haben uns verschrieben.

# %%
while zäler < 20:
    print(zähler)
    zähler = zähler + 1

# %% [markdown]
# Hiermit teilt uns die Programmiersprache mit, dass wir uns verschrieben haben. Freundlicherweise erfahren wir auch gleich in welcher Zeile wir uns verschrieben haben. Somit können wir den Fehler leicht beheben.

# %%
while zähler < 20:
    print(zähler)
    zähler = zähler + 1

# %% [markdown]
# ## For-Schleife im Detail
#
# Nun kommen wir erneut auf die **for** Schleife zu sprechen. Denn diese ist sehr vielseitig.
#
# ![For-Schleife](01--Schleifen/python-for-schleife-aufbau.jpg)
# Das Diagramm zeigt den genauen Aufbau der **for** Schleife.

# %% [markdown]
# ### Beispiel: Strings durchzählen

# %%
for buchstabe in 'Python':
    print(buchstabe)

# %% [markdown]
# ### Beispiel: Bereich mit Anfang und Ende

# %%
for zahl in range(3, 8):
    print(zahl)

# %% [markdown]
# ### Beispiel: In Zweierschritten zählen

# %%
for zahl in range(3, 8, 2):
    print(zahl)

# %% [markdown]
# ## Listen
#
# Listen lassen sich besonders gut abzählen. Dabei können wir bestimmte Anweisungen für jedes **Element** in der Liste ausführen.

# %% [markdown]
# ### Beispiel: Eine Liste durchzählen

# %%
fruchtListe = ['Apfel', 'Banane', 'Orange', 'Kiwi']

# %%
for element in fruchtListe:
    print(element)

# %% [markdown]
# ## Break-Anweisung
#
# Mithilfe der **break** Anweisung (engl. Ausbrechen) können wir Schleifen jederzeit beenden.

# %%
while True:
    print(zähler)
    if zähler > 30:
        break
    zähler = zähler + 1

# %% [markdown]
# ## Continue-Anweisung
#
# Die **continue** (engl. Fortfahren) Anweisung startet die Schleife neu.

# %%
while True:
    print(zähler)
    if zähler < 40:
        zähler = zähler + 1
        continue
    else:
        break

# %% [markdown]
# ## Schleife in Schleife
#
# Nun kommen wir zu einer besonderen Herausforderung. Man kann Schleifen in Schleifen verschachteln. Was dann passiert und warum man das tun sollte, zeigen wir Dir anhand folgendem Beispiel.
#
# Angenommen wir wollen, dass der Computer das kleine Einmaleins für uns rechnet. Mit anderen Worten: Jede Zahl eines Bereichs von 1 bis 10 soll mit jeder Zahl eines anderen Bereichs multipliziert werden.
#
# Beachte, dass die **range** Funktion das Ende nicht mitzählt, d.h. wir nutzen **range(1, 11)** für alle Zahlen von 1 bis 10.

# %%
for zahl1 in range(1, 11):
    for zahl2 in range(1, 11):
        print(zahl1, '*', zahl2, '=', zahl1 * zahl2)
# Out:
# 1 * 1 = 1
# 1 * 2 = 2
# 1 * 3 = 3
# 1 * 4 = 4
# 1 * 5 = 5
# 1 * 6 = 6
# 1 * 7 = 7
# 1 * 8 = 8
# 1 * 9 = 9
# 1 * 10 = 10
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 4 * 10 = 40
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
# 6 * 10 = 60
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 7 * 10 = 70
# 8 * 1 = 8
# 8 * 2 = 16
# 8 * 3 = 24
# 8 * 4 = 32
# 8 * 5 = 40
# 8 * 6 = 48
# 8 * 7 = 56
# 8 * 8 = 64
# ...

# %% [markdown]
# ## Warum macht die Schleife nicht was ich will? Wie man Fehler findet
#
# Eine gute Methode, um Fehler zu finden, ist **print** zu benutzen. Hierdurch kann man jederzeit sichtbar machen, was die Schleife eigentlich tut.
#
# Dabei sollte man jedoch beachten, dass eine Schleife sehr schnell abläuft und somit eine wahre Flut von Daten produziert.
#
# Besonders bei verschachtelten Schleifen kann es somit leicht unübersichtlich werden.

# %% [markdown]
# ### Tabelle ausgeben
#
# Man kann eine verschachtelte Schleife als Tabelle ausgeben, um den Überblick zu behalten.
#
# Folgendes Beispiel zeigt Dir wie es geht. In diesem Beispiel lassen wir den Computer wieder das Einmaleins berechnen. Für alle Zahlen von 1 bis 10 machen wir Multiplikation mit den Zahlen von 1 bis 5.
#
# Die "äußere" Schleife, die von 1 bis 10 läuft, wird in den Zeilen der Tabelle dargestellt (von oben nach unten).
#
# Die "innere" Schleife, die von 1 bis 5 läuft, wird in den Spalten der Tabelle dargestellt (von links nach rechts).
#
# Man kann somit jede Berechnung, die der Computer gemacht hat, leicht überprüfen.

# %%
# Für jede Spalte Zahl 2 angeben
print('\t 1', '2', '3', '4', '5', sep='\t         ')
for zahl1 in range(1, 11):
    print('') # Leerzeile
    print(zahl1, end='\t') # Für jede Zeile Zahl 1 angeben
    for zahl2 in range(1, 6):
        print(zahl1, '*', zahl2, '=', zahl1 * zahl2, end='\t')
# Out:
# 	 1	         2	         3	         4	         5
#
# 1	1 * 1 = 1	1 * 2 = 2	1 * 3 = 3	1 * 4 = 4	1 * 5 = 5
# 2	2 * 1 = 2	2 * 2 = 4	2 * 3 = 6	2 * 4 = 8	2 * 5 = 10
# 3	3 * 1 = 3	3 * 2 = 6	3 * 3 = 9	3 * 4 = 12	3 * 5 = 15
# 4	4 * 1 = 4	4 * 2 = 8	4 * 3 = 12	4 * 4 = 16	4 * 5 = 20
# 5	5 * 1 = 5	5 * 2 = 10	5 * 3 = 15	5 * 4 = 20	5 * 5 = 25
# 6	6 * 1 = 6	6 * 2 = 12	6 * 3 = 18	6 * 4 = 24	6 * 5 = 30
# 7	7 * 1 = 7	7 * 2 = 14	7 * 3 = 21	7 * 4 = 28	7 * 5 = 35
# 8	8 * 1 = 8	8 * 2 = 16	8 * 3 = 24	8 * 4 = 32	8 * 5 = 40
# 9	9 * 1 = 9	9 * 2 = 18	9 * 3 = 27	9 * 4 = 36	9 * 5 = 45
# 10	10 * 1 = 10	10 * 2 = 20	10 * 3 = 30	10 * 4 = 40	10 * 5 = 50

# %% [markdown]
# ## Übungsfeld für Python Schleifen

# %%
# Übungsfeld für Schleifen

for zahl in range(5):
    print(zahl)
    
    
# Hier könnte Dein Code stehen

# %% [markdown]
# ## Weiterführende Fragen
#
# ### Was macht enumerate() in einer For Schleife in Python?
#
#
# ### Wie nutzt man Listen und Sets in einer Python For Schleife?
